# %%
# modules loads
import os
import pandas as pd
import numpy as np
import matplotlib
from matplotlib import pyplot
from sklearn.ensemble import RandomForestRegressor
from sklearn.model_selection import train_test_split
from sklearn import metrics
import requests
import json
import matplotlib.font_manager as fm

# %%
fm.findSystemFonts()
matplotlib.font_manager._rebuild()
#matplotlib.rcParams['font.family'] = 'IPAexGothic'

print(matplotlib.matplotlib_fname()) #設定ファイルを表示（matplotlibrcは後で作ります）
print(matplotlib.rcParams['font.family']) #現在使用しているフォントを表示
print(matplotlib.get_configdir()) #設定ディレクトリを表示
print(matplotlib.get_cachedir()) #キャッシュディレクトリを表示
# Out:
# Matplotlib is building the font cache; this may take a moment.
# /home/jovyan/.config/matplotlib/matplotlibrc
# ['IPAexGothic']
# /home/jovyan/.config/matplotlib
# /home/jovyan/.cache/matplotlib

# %%
df = pd.read_csv('../output_calc.csv')
print(df)
# Out:
#               日付  9201_前日比  9201_翌日比  4506_前日比  4506_翌日比  4307_前日比  4307_翌日比  \
# 0     2016-01-04       0.0      18.0       0.0     -17.0       0.0     -60.0
# 1     2016-01-05      18.0     -52.0     -17.0     -14.0     -60.0    -190.0
# 2     2016-01-06     -52.0       1.0     -14.0       9.0    -190.0     -15.0
# 3     2016-01-07       1.0     -48.0       9.0     -14.0     -15.0      35.0
# 4     2016-01-08     -48.0    -137.0     -14.0     -47.0      35.0    -135.0
# ...          ...       ...       ...       ...       ...       ...       ...
# 1229  2021-01-29     -50.0       1.0     124.0      55.0     265.0      -5.0
# 1230  2021-02-01       1.0      41.0      55.0      15.0      -5.0       0.0
# 1231  2021-02-02      41.0     125.0      15.0     -21.0       0.0      85.0
# 1232  2021-02-03     125.0     210.0     -21.0     -44.0      85.0       0.0
# 1233  2021-02-12     210.0       0.0     -44.0       0.0       0.0       0.0
#
#       9202_前日比  9202_翌日比  6047_前日比  6047_翌日比  4755_前日比  4755_翌日比
# 0          0.0      -0.1       0.0      16.0       0.0     -35.0
# 1         -0.1      -0.8      16.0     -32.0     -35.0     -45.0
# 2         -0.8      -4.3     -32.0     -26.0     -45.0     -30.5
# 3         -4.3      -2.8     -26.0      -4.0     -30.5      -5.5
# 4         -2.8      -8.7      -4.0     -29.0      -5.5     -53.0
# ...        ...       ...       ...       ...       ...       ...
# 1229     -55.0       1.0     -26.0       9.0     -28.0     -16.0
# 1230       1.0      38.5       9.0      21.0     -16.0      31.0
# 1231      38.5      65.5      21.0       2.0      31.0      21.0
# 1232      65.5      66.0       2.0      18.0      21.0     122.0
# 1233      66.0       0.0      18.0       0.0     122.0       0.0
#
# [1234 rows x 13 columns]

# %%
#pyplot.figure()
#df.plot(x='日付',y='9201_前日比')
df.plot(x='日付', subplots=True, layout=(8, 2), sharex=True, sharey=False, figsize=(50,50))
# Out:
# array([[<AxesSubplot:xlabel='日付'>, <AxesSubplot:xlabel='日付'>],
#        [<AxesSubplot:xlabel='日付'>, <AxesSubplot:xlabel='日付'>],
#        [<AxesSubplot:xlabel='日付'>, <AxesSubplot:xlabel='日付'>],
#        [<AxesSubplot:xlabel='日付'>, <AxesSubplot:xlabel='日付'>],
#        [<AxesSubplot:xlabel='日付'>, <AxesSubplot:xlabel='日付'>],
#        [<AxesSubplot:xlabel='日付'>, <AxesSubplot:xlabel='日付'>],
#        [<AxesSubplot:xlabel='日付'>, <AxesSubplot:xlabel='日付'>],
#        [<AxesSubplot:xlabel='日付'>, <AxesSubplot:xlabel='日付'>]],
#       dtype=object)
